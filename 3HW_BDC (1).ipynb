# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from skimage import data
import numpy as np
from matplotlib import pyplot as plt

random_image = np.random.random([500, 500])

plt.imshow(random_image, cmap='gray')
plt.colorbar();

# %%
image = data.coins()
print('Type:', type(image))
print('dtype:', image.dtype)
print('shape:', image.shape)

plt.imshow(image, cmap='gray');
# Out:
# Type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (303, 384)

# %%
print('The image as array is:')
print(image)
# Out:
# The image as array is:
# [[ 47 123 133 ...  14   3  12]
#  [ 93 144 145 ...  12   7   7]
#  [126 147 143 ...   2  13   3]
#  ...
#  [ 81  79  74 ...   6   4   7]
#  [ 88  82  74 ...   5   7   8]
#  [ 91  79  68 ...   4  10   7]]

# %%
from numpy import array
ar = array(image)
ar
# Out:
# array([[ 47, 123, 133, ...,  14,   3,  12],
#        [ 93, 144, 145, ...,  12,   7,   7],
#        [126, 147, 143, ...,   2,  13,   3],
#        ...,
#        [ 81,  79,  74, ...,   6,   4,   7],
#        [ 88,  82,  74, ...,   5,   7,   8],
#        [ 91,  79,  68, ...,   4,  10,   7]], dtype=uint8)

# %%
from scipy.linalg import svd
U, s, VT = svd(ar)
print(U)
print(s)
print(VT)
# Out:
# [[-0.06557654 -0.03334925 -0.04674215 ... -0.10036755 -0.08512305
#   -0.07086508]
#  [-0.06535023 -0.03338917 -0.04808104 ...  0.20874223  0.22558771
#    0.20059744]
#  [-0.06490013 -0.03348762 -0.05041668 ... -0.15581891 -0.3296903
#   -0.30864483]
#  ...
#  [-0.02713638 -0.0227335   0.00643893 ...  0.00377487  0.00319061
#   -0.00428103]
#  [-0.02732459 -0.02452218  0.00710984 ... -0.00466843 -0.0173535
#    0.01638713]
#  [-0.02733641 -0.02504914  0.00470697 ...  0.00143346  0.01186786
#   -0.00979992]]
# [3.53049766e+04 6.98934375e+03 4.17880908e+03 3.79425195e+03
#  3.00355054e+03 2.83247681e+03 2.68315332e+03 2.56333374e+03
#  2.01050903e+03 1.76952429e+03 1.75026062e+03 1.68791455e+03
#  1.67644824e+03 1.51655530e+03 1.40628601e+03 1.38145715e+03
#  1.33756934e+03 1.25897107e+03 1.20819653e+03 1.16085779e+03
#  1.13591614e+03 1.11139807e+03 1.10131592e+03 1.07365332e+03
#  1.02795752e+03 1.00256342e+03 9.56521057e+02 9.37885559e+02
# ...

# %%
from numpy import array
from numpy import diag
from numpy import dot
from numpy import zeros
from scipy.linalg import svd
# define a matrix
A = ar
print(A)
# Singular-value decomposition
U, s, VT = svd(A)
# create m x n Sigma matrix
Sigma = zeros((A.shape[0], A.shape[1]))
# populate Sigma with n x n diagonal matrix
Sigma[:A.shape[1],  :A.shape[0]] = diag(s)
# reconstruct matrix
B = U.dot(Sigma.dot(VT))
print(B)
# Out:
# [[ 47 123 133 ...  14   3  12]
#  [ 93 144 145 ...  12   7   7]
#  [126 147 143 ...   2  13   3]
#  ...
#  [ 81  79  74 ...   6   4   7]
#  [ 88  82  74 ...   5   7   8]
#  [ 91  79  68 ...   4  10   7]]
# [[ 46.99996473 122.99998889 133.00003779 ...  13.99997      2.99993132
#    11.99992022]
#  [ 92.99631784 144.00565118 145.00093633 ...  11.99860511   6.99827214
#     6.99882096]
#  [126.0001452  146.99967901 143.00006493 ...   2.00000867  12.99996565
#     2.99995565]
#  ...
#  [ 80.99953019  78.9999422   74.0001512  ...   5.99997607   3.99998459
#     7.00004966]
#  [ 87.99964169  81.999896    74.00011173 ...   4.99996322   6.99999221
#     8.00008068]
#  [ 90.99936911  78.99970503  68.00017545 ...   3.99994491   9.9999741
#     7.00004132]]

# %%
import matplotlib.pyplot as plt

plt.imshow(B)
plt.show()

# %%
from numpy import array
from numpy import diag
from numpy import zeros
from scipy.linalg import svd
# define a matrix
A = ar
print(A)
# Singular-value decomposition
U, s, VT = svd(A)
# create m x n Sigma matrix
Sigma = zeros((A.shape[0], A.shape[1]))
# populate Sigma with n x n diagonal matrix
Sigma[:A.shape[0], :A.shape[0]] = diag(s)
# select
n_elements = int(303*0.5)# 0.05 0.1 0.25 0.5

Sigma = Sigma[:, :n_elements]
VT = VT[:n_elements, :]
# reconstruct
B = U.dot(Sigma.dot(VT))
print(B)
# transform
T = U.dot(Sigma)
print(T)
T = A.dot(VT.T)
print(T)
plt.imshow(B)
plt.show()
plt.imshow(T)
plt.show()
# Out:
# [[ 47 123 133 ...  14   3  12]
#  [ 93 144 145 ...  12   7   7]
#  [126 147 143 ...   2  13   3]
#  ...
#  [ 81  79  74 ...   6   4   7]
#  [ 88  82  74 ...   5   7   8]
#  [ 91  79  68 ...   4  10   7]]
# [[ 98.87433447 124.80432364 129.97760966 ...   6.10453726  -6.00832295
#     2.9160832 ]
#  [110.92604729 133.05480279 135.30053334 ...  12.71125911  -0.77340705
#     3.97376614]
#  [118.25844071 136.50841746 137.25636853 ...  18.1388186    3.91796379
#     3.44086447]
#  ...
#  [ 81.83412795  79.18025215  73.89194454 ...   2.30089661   4.20454295
#    10.13805225]
#  [ 81.69825358  78.30853917  72.02166702 ...   5.33631785   3.44908873
#    11.4996862 ]
#  [ 83.68474148  79.07490134  72.69457559 ...   4.91640075   2.89369649
#    10.93595953]]
# [[-2.31517815e+03 -2.33089395e+02 -1.95326531e+02 ...  7.62287742e+00
#    7.81434314e+00 -4.75749426e+00]
#  [-2.30718850e+03 -2.33368411e+02 -2.00921504e+02 ...  3.38040881e+00
#   -6.16215535e-01  3.09700253e-01]
# ...

# %% [markdown]
# here I considered each percentage and by raising the percentage the photo became more clear. And percent of the Frobenius norm of the matrix corresponding to the original
# picture is retained in each case, e.g.for 50% it was 0.999689153343282

# %%
import numpy as np
from numpy import linalg as LA
print('A matrix initial',LA.norm(A, 'fro'))
print('Reconstructed B',LA.norm(B, 'fro'))
print(LA.norm(B, 'fro')/LA.norm(A, 'fro'))
# Out:
# A matrix initial 37641.05839372746
# Reconstructed B 37629.35779657044
# 0.999689153343282
